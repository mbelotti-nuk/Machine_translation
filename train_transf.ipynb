# %%
from architecture.transformer_module import Transformer
from tokenization.tokenizer_module import language_set, spec_tokens, translation_tokenizer
from torch.utils.data import Dataset, DataLoader
import random
import numpy as np
import torch
import os
import gc
import copy
import random
from timeit import default_timer as timer

seed = 1996
torch.manual_seed(seed)
torch.mps.manual_seed(seed)
random.seed(seed)

# tokenizer
VOCAB_SIZE = 10_000
MAX_SEQUENCE_LEN = 30

# model
DEVICE = "mps"
BATCH_SIZE = 128
EMBEDDING_DIM = 256
N_LAYERS = 2
N_HEADS = 4
DROPOUT = 0.3

# %% [markdown]
# ### Set data

# %%
def get_data(file_path):
    txt = None
    with open(file_path) as f:
        txt = f.read().split("\n")
    txt = [t.strip() for t in txt]
    temp = []
    for t in txt:
        if len(t) > 0:
            temp.append(t)
    txt = temp
    return np.array(txt)


def split_train_test_val(it_data, fr_data, perc_test = 0.1, n_val_cases = 100):
    assert len(it_data) > n_val_cases
    assert len(it_data) - n_val_cases > 0
    n_train_test, n = len(it_data) - n_val_cases, len(it_data)
    n_test = int(n_train_test * (1-perc_test))
    indices = random.sample(range(len(it_data)), len(it_data))
    train_indices, test_indices, val_indices  = indices[:n_test], indices[n_test:-n_val_cases], indices[n-n_val_cases:]
    return (language_set(source=it_data[train_indices], target=fr_data[train_indices]), 
            language_set(source=it_data[test_indices], target=fr_data[test_indices]),
            language_set(source=it_data[val_indices], target=fr_data[val_indices]) )


root = "data/it_fr/"

it_data = get_data(os.path.join(root, "Tatoeba.fr-it.it"))
fr_data = get_data(os.path.join(root, "Tatoeba.fr-it.fr"))

train_data, test_data, val_data = split_train_test_val(it_data, fr_data)

# %%
class translation_dataset(Dataset):
    def __init__(self, data:language_set):
        self.data = data
        
    def __len__(self):
        return len(self.data.source)
    
    def __getitem__(self, idx):
        return self.data.source[idx], self.data.target[idx]

train_set = translation_dataset(train_data)
test_set =  translation_dataset(test_data)
val_set =   translation_dataset(val_data)

# %% [markdown]
# ### Tokenizer

# %%
tokenizer = translation_tokenizer(VOCAB_SIZE, MAX_SEQUENCE_LEN)
tokenizer.set_tokenizers(language_set(source=[*train_data.source, *test_data.source], target=[*train_data.target, *test_data.target]))

# %%
tokenizer.save_tokenizer("models")

# %%
print(tokenizer.src_wrap.vocab)
# Out:
# {'deceduta': 8997, '##ira': 1608, 'manif': 8661, '##ccio': 928, 'prote': 1892, '##dizione': 2876, 'accompagnera': 3326, 'ringraziarti': 6046, '##de': 256, 'batta': 3715, 'lamenta': 3865, 'solita': 9365, '“': 84, '##d': 100, 'divorziare': 5461, 'imbara': 7640, 'alg': 3777, 'nelle': 2970, 'gira': 3753, '##din': 9185, 'diventati': 6291, 'ripara': 6244, 'riparare': 2200, '##00': 2178, '##mono': 9205, 'accendera': 4409, 'rivoluzione': 9771, 'scoppio': 8961, 'tutto': 479, 'bicchi': 2082, 'coprire': 6309, '##pazione': 7235, 'dirtelo': 4855, 'minogue': 8891, 'mar': 260, 'nevicato': 6304, 'investi': 4554, 'brontola': 7038, 'feste': 5307, 'matema': 9700, 'olimp': 9950, 'obbligati': 9745, 'otto': 2010, 'residenziale': 7091, 'scom': 3445, 'accesso': 4322, 'rispettato': 5983, 'stu': 377, 'lavavate': 7337, 'richia': 2845, 'riusci': 2506, 'interprete': 7060, 'tossi': 4436, 'apro': 8106, 'consultare': 6579, '
# %%
for k in range(0,1):
    i=random.randint(0, len(train_data.source))
    print(tokenizer.src_wrap(train_data.source[i]).tokens(), 
          tokenizer.trg_wrap(train_data.target[i]).tokens())
    
    print(tokenizer.src_wrap.encode(train_data.source[i]), 
          tokenizer.trg_wrap.encode(train_data.target[i]))
    
    print(tokenizer.src_wrap.decode(tokenizer.src_wrap.encode(train_data.source[i])), 
          tokenizer.trg_wrap.decode(tokenizer.trg_wrap.encode(train_data.target[i])))
    print()
# Out:
# ['[SOS]', 'linda', 'seguira', 'il', 'vostro', 'consiglio', '.', '[EOS]'] ['[SOS]', 'linda', 'va', 'suivre', 'votre', 'conseil', '.', '[EOS]']
# [1, 1086, 5688, 168, 757, 1504, 15, 2] [1, 1049, 262, 1873, 340, 1423, 16, 2]
# [SOS] linda seguira il vostro consiglio. [EOS] [SOS] linda va suivre votre conseil. [EOS]

# %% [markdown]
# ### Define model

# %%
SRC_VOCAB_SIZE = len(tokenizer.src_wrap)
TRG_VOCAB_SIZE = len(tokenizer.trg_wrap)
model = Transformer(SRC_VOCAB_SIZE, TRG_VOCAB_SIZE, N_LAYERS, N_HEADS, EMBEDDING_DIM, MAX_SEQUENCE_LEN, dropout=DROPOUT).to(DEVICE)

# %%
def collate_func(batch):
    src, trg = [], []
    for b in batch:
        src.append(b[0])
        trg.append(b[1])
    src_tokens, trg_tokens = tokenizer(src, trg)

    src_batch, target_batch = torch.tensor( src_tokens , dtype=torch.long ) , torch.tensor( trg_tokens, dtype=torch.long  )
        
    return src_batch, target_batch[:,:-1], target_batch[:, 1:]

# %%
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, collate_fn=collate_func)
test_loader =  DataLoader(test_set, batch_size=BATCH_SIZE,  collate_fn=collate_func)

# %%
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=tokenizer.pad_id(), label_smoothing=0.2)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, betas=(0.9, 0.98), eps=1e-9)

# %% [markdown]
# ### Training functions

# %%
def train_fn(model:Transformer, data_loader, optimizer, device, clip=1):
    model.train()
    epoch_loss = 0
    optimizer.zero_grad()   
    for src, trg_in, trg_out in data_loader:
        src, trg_in, trg_out = src.to(device), trg_in.to(device), trg_out.to(device)
        # get masks
        e_mask, d_mask = model.get_masks(src, trg_in, tokenizer.pad_id())
        # compute logits
        out_model = model(src, trg_in, e_mask, d_mask)
        logits = model.get_logits(out_model) 
        # zero the gradients
        optimizer.zero_grad()
        # compute loss
        loss = loss_fn(logits.contiguous().view(-1, TRG_VOCAB_SIZE), trg_out.contiguous().view(-1))
        # update gradients
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        epoch_loss += loss.item()
    return epoch_loss / len(data_loader)

def evaluate_fn(model:Transformer, data_loader, device):
    model.eval()
    epoch_loss = 0
    with torch.no_grad():
        for src, trg_in, trg_out in data_loader:
            src, trg_in, trg_out = src.to(device), trg_in.to(device), trg_out.to(device)
            # get masks
            e_mask, d_mask = model.get_masks(src, trg_in, tokenizer.pad_id())
            # compute logits
            out_model = model(src, trg_in, e_mask, d_mask)
            logits = model.get_logits(out_model) 
            # get loss
            loss = loss_fn(logits.contiguous().view(-1, TRG_VOCAB_SIZE), trg_out.contiguous().view(-1))
            epoch_loss += loss.item()           
    return epoch_loss / len(data_loader)


def translate_sentence( sentence:str, model:Transformer):
    model.eval()
    with torch.no_grad():
        in_tokens = tokenizer.src_wrap(sentence)["input_ids"]

        in_tensor = torch.ones(MAX_SEQUENCE_LEN, dtype=torch.int64) * tokenizer.pad_id()
        in_tensor[:len(in_tokens)] = torch.tensor(in_tokens)
        in_tensor = in_tensor.unsqueeze(0).to(DEVICE)
        #in_tensor = torch.tensor( in_tokens ).unsqueeze(0).to(DEVICE)
        e_mask = model.make_src_mask(in_tensor, tokenizer.pad_id())
        memory = model.encode(in_tensor, e_mask)
        
        out_tokens = torch.ones(1).fill_(tokenizer.sos_id()).type(in_tensor.dtype).to(DEVICE)
        #out_tokens = torch.ones(MAX_SEQUENCE_LEN).fill_(tokenizer.sos_id()).type(in_tensor.dtype).to(DEVICE)
        
        for i in range(MAX_SEQUENCE_LEN):
            d_mask = model.subsequent_mask(out_tokens.size(0)).type_as(in_tensor.data)     
            decoder_output = model.decode(memory, out_tokens.unsqueeze(0), e_mask, d_mask) # (1, L, d_model)

            probabilities = model.get_probabilities(decoder_output) # (1, L, trg_vocab_size)
            max_probabs = torch.argmax(probabilities, dim=-1).squeeze(0) # (L)å
            predicted_token = max_probabs[-1].item()
            out_tokens[i] = predicted_token
            out_tokens = torch.cat( [out_tokens, torch.empty(1).type_as(in_tensor).fill_(predicted_token)], dim=0 )
            if i >= MAX_SEQUENCE_LEN-1 or predicted_token == tokenizer.eos_token_ids:
                break   
        return "".join( tokenizer.decode( out_tokens.cpu().tolist()) )

# %%
NUM_EPOCHS=20

gc.collect()
os.environ["TOKENIZERS_PARALLELISM"] = "false"

train_loss_list, valid_loss_list = [], []
torch.mps.empty_cache()  

best_valid_loss = float("inf")
best_model = copy.deepcopy(model)
sentence = test_data.source[0]
for epoch in range(NUM_EPOCHS):
    start_time = timer()
    train_loss = train_fn( model, train_loader, optimizer, DEVICE)
    valid_loss = evaluate_fn( model, test_loader, DEVICE )
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        best_model = copy.deepcopy(model)
        torch.save(model.state_dict(), os.path.join("models", "checkpoint.pt"))
    end_time = timer()  
    print(f"Epoch: {epoch+1:02}\t time = {(end_time - start_time):.3f}s")
    print(f"\tTrain Loss: {train_loss:7.3f} | Train PPL: {np.exp(train_loss):7.3f}")
    print(f"\tValid Loss: {valid_loss:7.3f} | Valid PPL: {np.exp(valid_loss):7.3f}")
    print(f"Original text: {sentence}")
    print(f"Translated text: {translate_sentence(sentence, best_model)}")
    print()
# Out:
# Epoch: 01	 time = 28.463s
# 	Train Loss:   5.719 | Train PPL: 304.488
# 	Valid Loss:   5.063 | Valid PPL: 158.016
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'avez pas l'argent.
#
# Epoch: 02	 time = 32.748s
# 	Train Loss:   4.749 | Train PPL: 115.518
# 	Valid Loss:   4.413 | Valid PPL:  82.538
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous ne faites pas prendre bougies dans sa chambre.
#
# Epoch: 03	 time = 39.623s
# 	Train Loss:   4.251 | Train PPL:  70.177
# 	Valid Loss:   4.003 | Valid PPL:  54.757
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'aurez pas allume de bougies dans votre chambre.
#
# Epoch: 04	 time = 32.772s
# 	Train Loss:   3.916 | Train PPL:  50.194
# 	Valid Loss:   3.775 | Valid PPL:  43.584
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous ne pousse pas de bougies dans votre chambre.
#
# Epoch: 05	 time = 32.272s
# 	Train Loss:   3.696 | Train PPL:  40.283
# 	Valid Loss:   3.624 | Valid PPL:  37.473
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allume pas de bougies dans votre chambre.
#
# Epoch: 06	 time = 32.081s
# 	Train Loss:   3.542 | Train PPL:  34.534
# 	Valid Loss:   3.517 | Valid PPL:  33.693
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allume pas de bougies dans votre chambre.
#
# Epoch: 07	 time = 34.305s
# 	Train Loss:   3.424 | Train PPL:  30.692
# 	Valid Loss:   3.438 | Valid PPL:  31.137
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumiez pas de bougies dans votre chambre.
#
# Epoch: 08	 time = 40.787s
# 	Train Loss:   3.335 | Train PPL:  28.091
# 	Valid Loss:   3.385 | Valid PPL:  29.523
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumez pas de bougies dans votre chambre.
#
# Epoch: 09	 time = 32.305s
# 	Train Loss:   3.265 | Train PPL:  26.187
# 	Valid Loss:   3.334 | Valid PPL:  28.063
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allume pas de bougies dans votre chambre.
#
# Epoch: 10	 time = 34.798s
# 	Train Loss:   3.208 | Train PPL:  24.734
# 	Valid Loss:   3.298 | Valid PPL:  27.046
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumez pas de bougies dans votre chambre.
#
# Epoch: 11	 time = 36.311s
# 	Train Loss:   3.161 | Train PPL:  23.599
# 	Valid Loss:   3.269 | Valid PPL:  26.291
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumer des bougies dans votre chambre.
#
# Epoch: 12	 time = 41.593s
# 	Train Loss:   3.120 | Train PPL:  22.657
# 	Valid Loss:   3.244 | Valid PPL:  25.647
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumer des bougies dans votre chambre.
#
# Epoch: 13	 time = 36.809s
# 	Train Loss:   3.086 | Train PPL:  21.893
# 	Valid Loss:   3.220 | Valid PPL:  25.034
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumerz pas de bougies dans votre chambre.
#
# Epoch: 14	 time = 37.344s
# 	Train Loss:   3.057 | Train PPL:  21.271
# 	Valid Loss:   3.204 | Valid PPL:  24.627
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumerz pas de bougies dans votre chambre.
#
# Epoch: 15	 time = 39.113s
# 	Train Loss:   3.032 | Train PPL:  20.740
# 	Valid Loss:   3.184 | Valid PPL:  24.155
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumer des bougies dans votre chambre.
#
# Epoch: 16	 time = 40.331s
# 	Train Loss:   3.009 | Train PPL:  20.263
# 	Valid Loss:   3.172 | Valid PPL:  23.864
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumerz pas de bougies dans votre chambre.
#
# Epoch: 17	 time = 41.443s
# 	Train Loss:   2.988 | Train PPL:  19.855
# 	Valid Loss:   3.157 | Valid PPL:  23.497
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allume pas de bougies dans votre chambre.
#
# Epoch: 18	 time = 40.933s
# 	Train Loss:   2.970 | Train PPL:  19.500
# 	Valid Loss:   3.155 | Valid PPL:  23.448
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumerz pas de bougies dans votre chambre.
#
# Epoch: 19	 time = 40.627s
# 	Train Loss:   2.953 | Train PPL:  19.170
# 	Valid Loss:   3.143 | Valid PPL:  23.181
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumerz pas de bougies dans votre chambre.
#
# Epoch: 20	 time = 40.752s
# 	Train Loss:   2.938 | Train PPL:  18.884
# 	Valid Loss:   3.133 | Valid PPL:  22.940
# Original text: Voi non accenderete delle candele nella vostra camera.
# Translated text: vous n'allumerz pas de bougies dans votre chambre.

# %%
torch.save(best_model, 'models/model.pth')

# %%
n_val = 4
sentence = val_data.source[n_val]
translation = translate_sentence(sentence, best_model)

print(f"Original text:\t\t{sentence}")
print(f"Translated text:\t{translation}")
print(f"Real:\t\t\t{val_data.target[n_val]}")
# Out:
# Original text:		Corregga quegli errori.
# Translated text:	corrigez ces fautes.
# Real:			Corrigez ces fautes.

# %%
translate_sentence("mi manchi amore mio", best_model)
# Out:
# 'tu me manques mon amour.'
